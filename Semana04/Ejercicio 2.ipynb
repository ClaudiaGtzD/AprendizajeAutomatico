# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import matplotlib.dates as mdates

# %%
datos = pd.read_excel("./Información Planta Solar v3 pdn.xlsx")

# %%
datos['iNumDia'] = datos['dtDia'].dt.day
datoslimpios = datos.drop(columns=['dtDia', 'iCodMes', 'iCodDiaUniversal', 'iCodHora', 'vchDesCondCielo', 'vchDesDirViento'])
datoslimpios['Fecha'] = pd.to_datetime(dict(year=datoslimpios.iCodAno, month=datoslimpios.iNumMes, day=datoslimpios.iNumDia, hour=datoslimpios.iHoraUniversal))

# %%
datoslimpios.describe()
# Out:
#             iCodAno       iNumMes  iHoraUniversal       fltSuma       fltTemp  \
# count  18946.000000  18946.000000    18946.000000  18946.000000  18946.000000
# mean    2022.074686      6.618072       11.502164   9748.432925     18.432957
# min     2021.000000      1.000000        0.000000      0.000000      0.000000
# 25%     2022.000000      4.000000        6.000000      0.000000     14.400000
# 50%     2022.000000      7.000000       12.000000    371.220200     18.000000
# 75%     2023.000000      9.000000       18.000000  23559.494075     22.900000
# max     2023.000000     12.000000       23.000000  29966.138600     36.400000
# std        0.731716      3.318434        6.923663  12091.548030      6.063001
#
#        fltProbabilidadLluvia  fltHumedadRelativa  fltVelocidadViento  \
# count           18946.000000        18944.000000         18946.00000
# mean                5.754091           57.848406            11.97553
# ...
