# %% [markdown]
# # Tarea 01: Elección de un conjunto de datos

# %% [markdown]
# Para este curso, he elegido trabajar con un conjunto de datos, que reúnde la información de la generación de energía de un panel solar en México y las condiciones ambientales que se tenían en el momento.
#
# El conjunto de datos lo tomé de la empresa donde laboro, ya que allí utilizamos la historia de lo que genera la planta de paneles solares, junto con las condiciones del lugar donde se encuentran, para poder hacer las predicciones de la futura generación y así realizar las estrategias de compra y venta del mercado energético.

# %% [markdown]
# De la información, tenemos la generación, la cual está en kW, la fecha de esa lectura, el indicador de si es con fecha de verano o invierno, el periodo que abarca y la radiación.

# %%
import pandas as pd

generacion = pd.read_excel('../Datasets/Información Planta Solar.xlsx', 'Inyecciones')
generacion.head()
# Out:
#          dtCalendario  iBitVeranoInvierno vchCodBitHorarioSSB  \
# 0 2020-03-01 00:05:00                   1                   B
# 1 2020-03-01 00:10:00                   1                   B
# 2 2020-03-01 00:15:00                   1                   B
# 3 2020-03-01 00:20:00                   1                   B
# 4 2020-03-01 00:25:00                   1                   B
#
#                                     vchDesPeriodoSSB  fltInyeccion  \
# 0  Del último domingo de octubre al sábado anteri...           0.0
# 1  Del último domingo de octubre al sábado anteri...           0.0
# 2  Del último domingo de octubre al sábado anteri...           0.0
# 3  Del último domingo de octubre al sábado anteri...           0.0
# 4  Del último domingo de octubre al sábado anteri...           0.0
#
#    fltRadiacionSolar
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# En otra de las pestañas tenemos la historia horaria de las condiciones ambientales presentadas, la hora, la temperatura, presión atmosférica, humedad, velocidad y dirección del viento, cobertura de las nubes, entre otros.

# %%
condicionesAmbientales = pd.read_excel('../Datasets/Información Planta Solar.xlsx', 'Condiciones ambientales')
condicionesAmbientales.head()
# Out:
#       vchDesCiudad      dtDia              dtHora  iNumHora  fltTemp  \
# 0  Villa de Arista 2020-05-19 2020-05-19 08:00:00         8    19.36
# 1  Villa de Arista 2020-05-19 2020-05-19 09:00:00         9    22.11
# 2  Villa de Arista 2020-05-19 2020-05-19 10:00:00        10    25.13
# 3  Villa de Arista 2020-05-19 2020-05-19 11:00:00        11    27.45
# 4  Villa de Arista 2020-05-19 2020-05-19 12:00:00        12    29.86
#
#    fltPresionAtmosferica  fltProbabilidadLluvia  fltHumedadRelativa  \
# 0                    NaN                    0.0               73.20
# 1                    NaN                    0.0               65.23
# 2                    NaN                    0.0               55.31
# 3                    NaN                    0.0               44.47
# 4                    NaN                    0.0               35.22
#
#    fltVelocidadViento  fltDireccionViento  vchDireccionViento  \
# 0                2.90               66.80                 NaN
# ...

# %% [markdown]
# Decidí tomar este tema, ya que es un tema que me interesa mucho ya que el mercado energético renovable en México se encuentran a la alza, y creo que es un tema que me servirá profesionalmente y me ayudará a poner en práctica en vivo todo el conocimiento que adquiera durante este curso e incluso, la maestría entera.
#
# Para este curso, me interesa mucho poder hacer más eficiente las predicciones de la generación en los futuros días, reducir el porcentaje de error entre lo pronosticado y lo que fue en realidad y que actúe de manera inteligente en el futuro.
