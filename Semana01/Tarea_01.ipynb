# %% [markdown]
# # Tarea 01: Elección de un conjunto de datos

# %% [markdown]
# Para este curso, he elegido trabajar con un conjunto de datos, que reúnde la información de la generación de energía de un panel solar y las condiciones ambientales que se tenían en el momento.
#
# El conjunto de datos lo tomé de Kaggle: [Renewable Energy and Weather Conditions]("https://www.kaggle.com/datasets/samanemami/renewable-energy-and-weather-conditions")

# %%
import pandas as pd

data = pd.read_csv('./solar_weather.csv')
data.head()
# Out:
#                   Time  Energy delta[Wh]  GHI  temp  pressure  humidity  \
# 0  2017-01-01 00:00:00                 0  0.0   1.6      1021       100
# 1  2017-01-01 00:15:00                 0  0.0   1.6      1021       100
# 2  2017-01-01 00:30:00                 0  0.0   1.6      1021       100
# 3  2017-01-01 00:45:00                 0  0.0   1.6      1021       100
# 4  2017-01-01 01:00:00                 0  0.0   1.7      1020       100
#
#    wind_speed  rain_1h  snow_1h  clouds_all  isSun  sunlightTime  dayLength  \
# 0         4.9      0.0      0.0         100      0             0        450
# 1         4.9      0.0      0.0         100      0             0        450
# 2         4.9      0.0      0.0         100      0             0        450
# 3         4.9      0.0      0.0         100      0             0        450
# 4         5.2      0.0      0.0         100      0             0        450
#
#    SunlightTime/daylength  weather_type  hour  month
# ...

# %% [markdown]
# Decidí tomar este tema, ya que es un tema que actualmente manejan en mi trabajo, es un área de oportunidad muy grande puesto que la energía renovable es el futuro (debería ser lo de hoy, pero la 4T atacó). Las empresas de hoy en día, necesitan los pronósticos de generación, para poder predecir el mercado y las tarifas.
#
# Para este curso, me interesa mucho poder hacer las predicciones correctas de la generación de los paneles de acuerdo a los pronósiticos del clima (Accuweather, etc.). Encontrar una especie de patrón inteligente, que me permita automatizar el aprendizaje y que día a día se actualice para dar con la generación más acertada de acuerdo a la realidad.
